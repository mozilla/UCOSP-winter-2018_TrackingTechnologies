# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
"""
Jupyter Notebook for generating statistics from random files
Example workflow:
-create df from entity list
-generate random files
-generate count for # of scripts used per TDL
-visualise data in bar chart
"""

import pandas as pd
import sys
sys.path.append('..')
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import sample_data
from utils import load_data_util

# Do not truncate cell values
pd.set_option('display.max_colwidth', -1)
# %matplotlib inline

# %%
# Create df from entity list
result = sample_data.make_entity_list_df()
result["count"] = 0
result[0:4]
# Out:
#                             properties                                             resources                                                 sites  count
# 2leep.com  [2leep.com]                  [2leep.com]                                           {2leep.com}                                           0
# 33Across   [33across.com, tynt.com]     [33across.com, tynt.com]                              {33across.com, tynt.com}                              0
# 365Media   [aggregateintelligence.com]  [365dm.com, 365media.com, aggregateintelligence.com]  {aggregateintelligence.com, 365media.com, 365dm.com}  0
# 4INFO      [4info.com, adhaven.com]     [4info.com, adhaven.com]                              {4info.com, adhaven.com}                              0

# %%
# Load random files
files = load_data_util.load_random_data(10000, "false")
# files

# %%
# Get count for each TDL and call origin
result = sample_data.sample_random_files(files)
print result[0:10]
# Out:
# ('match found! ', 'script_url: ', u'googletagmanager.com', 'calledFrom: ', u'www.googletagmanager.com')
# ('match found! ', 'script_url: ', u'pinterest.com', 'calledFrom: ', u'assets.pinterest.com')
# ('match found! ', 'script_url: ', u'twitter.com', 'calledFrom: ', u'platform.twitter.com')
# ('match found! ', 'script_url: ', u'google.com', 'calledFrom: ', u'apis.google.com')
# ('match found! ', 'script_url: ', u'google.com', 'calledFrom: ', u'apis.google.com')
# ('match found! ', 'script_url: ', u'disqus.com', 'calledFrom: ', u'yourdictionaryltk.disqus.com')
# ('match found! ', 'script_url: ', u'hotjar.com', 'calledFrom: ', u'script.hotjar.com')
# ('match found! ', 'script_url: ', u'po.st', 'calledFrom: ', u'i.po.st')
# ('match found! ', 'script_url: ', u'doubleclick.net', 'calledFrom: ', u'securepubads.g.doubleclick.net')
# ('match found! ', 'script_url: ', u'google.com', 'calledFrom: ', u'apis.google.com')
# ('match found! ', 'script_url: ', u'facebook.net', 'calledFrom: ', u'connect.facebook.net')
# ('match found! ', 'script_url: ', u'googlesyndication.com', 'calledFrom: ', u'tpc.googlesyndication.com')
# ('match found! ', 'script_url: ', u'doubleclick.net', 'calledFrom: ', u'googleads.g.doubleclick.net')
# ('match found! ', 'script_url: ', u'googlesyndication.com', 'calledFrom: ', u'tpc.googlesyndication.com')
# ('match found! ', 'script_url: ', u'googlesyndication.com', 'calledFrom: ', u'tpc.googlesyndication.com')
# ('match found! ', 'script_url: ', u'googlesyndication.com', 'calledFrom: ', u'tpc.googlesyndication.com')
# ('match found! ', 'script_url: ', u'googlesyndication.com', 'calledFrom: ', u'pagead2.googlesyndication.com')
# ('match found! ', 'script_url: ', u'newrelic.com', 'calledFrom: ', u'js-agent.newrelic.com')
# ('match found! ', 'script_url: ', u'googletagmanager.com', 'calledFrom: ', u'www.googletagmanager.com')
# ('match found! ', 'script_url: ', u'gstatic.com', 'calledFrom: ', u'www.gstatic.com')
# ('match found! ', 'script_url: ', u'cloudfront.net', 'calledFrom: ', u'd31qbv1cthcecs.cloudfront.net')
# ('match found! ', 'script_url: ', u'google-analytics.com', 'calledFrom: ', u'www.google-analytics.com')
# ('match found! ', 'script_url: ', u'criteo.net', 'calledFrom: ', u'static.criteo.net')
# ('match found! ', 'script_url: ', u'adroll.com', 'calledFrom: ', u's.adroll.com')
# ('match found! ', 'script_url: ', u'dynamicyield.com', 'calledFrom: ', u'static.dynamicyield.com')
# ('match found! ', 'script_url: ', u'cedexis.com', 'calledFrom: ', u'radar.cedexis.com')
# ('match found! ', 'script_url: ', u'googleadservices.com', 'calledFrom: ', u'www.googleadservices.com')
# ('match found! ', 'script_url: ', u'facebook.com', 'calledFrom: ', u'staticxx.facebook.com')
# ('match found! ', 'script_url: ', u'twitter.com', 'calledFrom: ', u'platform.twitter.com')
# ('match found! ', 'script_url: ', u'cbox.ws', 'calledFrom: ', u'static.cbox.ws')
# ('match found! ', 'script_url: ', u'doubleclick.net', 'calledFrom: ', u'securepubads.g.doubleclick.net')
# ('match found! ', 'script_url: ', u'newrelic.com', 'calledFrom: ', u'js-agent.newrelic.com')
# ('match found! ', 'script_url: ', u'google-analytics.com', 'calledFrom: ', u'www.google-analytics.com')
# ('match found! ', 'script_url: ', u'googleadservices.com', 'calledFrom: ', u'www.googleadservices.com')
# ('match found! ', 'script_url: ', u'criteo.net', 'calledFrom: ', u'static.criteo.net')
# ('match found! ', 'script_url: ', u'criteo.com', 'calledFrom: ', u'sslwidget.criteo.com')
# ('match found! ', 'script_url: ', u'facebook.com', 'calledFrom: ', u'staticxx.facebook.com')
# ('match found! ', 'script_url: ', u'addthis.com', 'calledFrom: ', u's7.addthis.com')
# ('match found! ', 'script_url: ', u'facebook.com', 'calledFrom: ', u'staticxx.facebook.com')
# ('match found! ', 'script_url: ', u'yandex.ru', 'calledFrom: ', u'mc.yandex.ru')
# ('match found! ', 'script_url: ', u'twitter.com', 'calledFrom: ', u'platform.twitter.com')
# ('match found! ', 'script_url: ', u'facebook.com', 'calledFrom: ', u'staticxx.facebook.com')
# ('match found! ', 'script_url: ', u'youtube.com', 'calledFrom: ', u'www.youtube.com')
# ('match found! ', 'script_url: ', u'doubleclick.net', 'calledFrom: ', u'securepubads.g.doubleclick.net')
# ('match found! ', 'script_url: ', u'facebook.net', 'calledFrom: ', u'connect.facebook.net')
# ('match found! ', 'script_url: ', u'criteo.net', 'calledFrom: ', u'static.criteo.net')
# ('match found! ', 'script_url: ', u'hotjar.com', 'calledFrom: ', u'script.hotjar.com')
# ('match found! ', 'script_url: ', u'everestads.net', 'calledFrom: ', u'dco-assets.everestads.net')
# ('match found! ', 'script_url: ', u'cnzz.com', 'calledFrom: ', u'w.cnzz.com')
# ('match found! ', 'script_url: ', u'cnzz.com', 'calledFrom: ', u'w.cnzz.com')
# ('match found! ', 'script_url: ', u'googlesyndication.com', 'calledFrom: ', u'pagead2.googlesyndication.com')
# ('match found! ', 'script_url: ', u'googlesyndication.com', 'calledFrom: ', u'pagead2.googlesyndication.com')
# ('match found! ', 'script_url: ', u'facebook.com', 'calledFrom: ', u'staticxx.facebook.com')
# ('match found! ', 'script_url: ', u'facebook.com', 'calledFrom: ', u'staticxx.facebook.com')
# ('match found! ', 'script_url: ', u'googlesyndication.com', 'calledFrom: ', u'pagead2.googlesyndication.com')
# ('match found! ', 'script_url: ', u'googlesyndication.com', 'calledFrom: ', u'tpc.googlesyndication.com')
# ('match found! ', 'script_url: ', u'googlesyndication.com', 'calledFrom: ', u'pagead2.googlesyndication.com')
# ('match found! ', 'script_url: ', u'googlesyndication.com', 'calledFrom: ', u'tpc.googlesyndication.com')
# ('match found! ', 'script_url: ', u'google-analytics.com', 'calledFrom: ', u'www.google-analytics.com')
# ('match found! ', 'script_url: ', u'googlesyndication.com', 'calledFrom: ', u'pagead2.googlesyndication.com')
# ('match found! ', 'script_url: ', u'criteo.net', 'calledFrom: ', u'static.criteo.net')
# ('match found! ', 'script_url: ', u'mail.ru', 'calledFrom: ', u'top-fwz1.mail.ru')
# ('match found! ', 'script_url: ', u'googleadservices.com', 'calledFrom: ', u'www.googleadservices.com')
# ('match found! ', 'script_url: ', u'googletagmanager.com', 'calledFrom: ', u'www.googletagmanager.com')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-b74abff03a0c> in <module>()
#       1 # Get count for each TDL and call origin
# ----> 2 result = sample_data.sample_random_files(files)
#       3 print result[0:10]
#
# /Users/mlopatka/repos/sb2018/analyses/sample_data.py in sample_random_files(files)
#      46             for site in result["sites"][j]:
#      47                 url = rowCalls["script_url"]
# ---> 48                 url = url.split("//")[1].split("/")[0]
#      49                 if site in url:
#      50                     if(not result.at[j, "calledFrom"]):
#
# IndexError: list index out of range

# %%
resultdata:image/png;base64,...
# Out:
#   File "<ipython-input-10-b72ccb51e5d7>", line 1
#     resultdata:image/png;base64,...
#               ^
# SyntaxError: invalid syntax
