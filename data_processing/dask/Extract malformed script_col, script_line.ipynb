# %% [markdown]
# Original data contained 2,059,735 files/locations but data cleaning stripped out locations because the data was malformed. Specifically the script_col and script_line values were not integers - that appear to have leaked from location.
#
# This notebook extracts that as a seperate dataset so we can see whether it contains something interesting.

# %%
import concurrent.futures
import dask.dataframe as dd
import json
import numpy as np
import pandas as pd

from ast import literal_eval
from dask.diagnostics import ProgressBar
from datetime import datetime
from pandas.api.types import CategoricalDtype
from path import Path
from tqdm import tqdm

PROJECT_DIR = Path.getcwd().parent  # Could assert some things here to check we got the right path
CACHE_OLD_DIR = Path.joinpath(PROJECT_DIR, 'cache')  # Where the originally downloaded files are
EXTRACTED_FILE = Path.joinpath(PROJECT_DIR, 'bad_lines.csv.gz')  # Where the bad files are going to live

fix_data = lambda x:  "[" + x[1:-1] + "]"

operation_categorical_type = CategoricalDtype(categories=["get", "set", "call", "set (failed)"])

# %%
index_file_path = Path.joinpath(PROJECT_DIR, 'file_index.txt')
assert index_file_path.exists(), 'Index File is missing'
index_file_path
# Out:
# Path('/home/bird/Dev/mozilla/sb2018/file_index.txt')

# %%
with open(index_file_path, 'r') as index_file:
    index = index_file.readlines()
    index = np.array([x.rstrip() for x in index])
index[0:4]
# Out:
# array(['1_00001314358470f0c99914d5c7af0cd89248e54883ac3b5083395b61.json',
#        '1_000014b53a60c645e3ac9bde6bae020430c930b3cc5903677e0d5cb2.json',
#        '1_00003e3765a73da45db5265de2b22424e025d61380f7cf8080b378aa.json',
#        '1_00004636d8310609e710934f194bfb41a5f0ac7ed5e05c0fb9047e48.json'],
#       dtype='<U63')

# %% [markdown]
# ## Process data

# %%
def get_data_from_file(file_name):
    fp = Path.joinpath(CACHE_OLD_DIR, file_name)
    with open(fp, 'r') as f:
        raw_data = f.read()
    data = json.loads(fix_data(raw_data))
    return data

def make_df_from_data(data, file_name):
    df = pd.DataFrame.from_records(data)
    df = df.reset_index()
    df['file_name'] = file_name
    # Make a unique call_id
    df = df.rename(columns=dict(index='call_id'))
    call_id_format = '{file_name}__{index:06d}'
    short_file_name = file_name.split('.json')[0]
    df.call_id = df.call_id.apply(lambda x: call_id_format.format(file_name=short_file_name, index=x))
    # Make a value len and initial value
    df['value_len'] = df.value.str.len()
    df['value_1000'] = df.value.str.slice(0, 1000)
    # Make a timestamp
    df['time_stamp'] = pd.to_datetime(df.time_stamp, errors='coerce')
    # Make categorical
    df['operation'] = df.operation.astype(operation_categorical_type)
    # Make script_col and script_line numeric, if errors, then return df
    try:
        df['script_col'] = pd.to_numeric(df.script_col)
        df['script_line'] = pd.to_numeric(df.script_line)
        return None
    except:
        return df

def get_df(file_name):
    data = get_data_from_file(file_name)
    df = make_df_from_data(data, file_name)
    return df

# %% [markdown]
# ### Test single write and read

# %%
# %%time
dfs = []
for file_name in index[0:1000]:
    dfs.append(get_df(file_name))

# %%
# %%time
all_df = pd.concat(dfs, ignore_index=True)
# Out:
# CPU times: user 2.38 ms, sys: 941 µs, total: 3.32 ms
# Wall time: 3.63 ms

# %%
all_df.head(10)
# Out:
#                                              call_id call_stack  crawl_id  \
# 0  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...                    1
# 1  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...                    1
# 2  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...                    1
# 3  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...                    1
# 4  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...                    1
# 5  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...                    1
# 6  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...                    1
# 7  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...                    1
# 8  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...                    1
# 9  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...                    1
#
#         func_name  in_iframe           location operation  \
# 0                       True  http://catfly.gr/       get
# 1              Zf       True  http://catfly.gr/       get
# 2              Zf       True  http://catfly.gr/       get
# 3              js       True  http://catfly.gr/       get
# 4              js       True  http://catfly.gr/       get
# 5              js       True  http://catfly.gr/       get
# 6              Cs       True  http://catfly.gr/       get
# 7              mq       True  http://catfly.gr/       get
# 8  likeUsBackShow      False  http://catfly.gr/       get
# 9            $h/<      False  http://catfly.gr/       get
#
#                               script_col script_line script_loc_eval  \
# 0                                  11209           1
# 1                                  27894           1
# 2                                  28026           1
# 3                                 170425           1
# 4                                 170439           1
# 5                                 170683           1
# 6                                 179602           1
# 7                                 130500           1
# 8  //cdn.catfly.com/js/script.js?01318aa        http
# 9                                  48170           1
#
#                                           script_url  \
# 0  http://pagead2.googlesyndication.com/pagead/js...
# 1  http://pagead2.googlesyndication.com/pagead/js...
# 2  http://pagead2.googlesyndication.com/pagead/js...
# 3  http://pagead2.googlesyndication.com/pagead/js...
# 4  http://pagead2.googlesyndication.com/pagead/js...
# 5  http://pagead2.googlesyndication.com/pagead/js...
# 6  http://pagead2.googlesyndication.com/pagead/js...
# 7  http://pagead2.googlesyndication.com/pagead/js...
# 8
# 9  http://pagead2.googlesyndication.com/pagead/js...
#
#                                               symbol              time_stamp  \
# 0                         window.navigator.userAgent 2017-12-16 17:52:15.130
# 1  window.navigator.plugins[Shockwave Flash].desc... 2017-12-16 17:52:15.149
# 2  window.navigator.plugins[Shockwave Flash].desc... 2017-12-16 17:52:15.149
# 3                         window.navigator.userAgent 2017-12-16 17:52:15.153
# 4                          window.navigator.platform 2017-12-16 17:52:15.154
# 5                           window.navigator.product 2017-12-16 17:52:15.154
# 6                           window.screen.colorDepth 2017-12-16 17:52:15.168
# 7                         window.navigator.userAgent 2017-12-16 17:52:15.207
# 8                                window.localStorage 2017-12-16 17:52:14.701
# 9                         window.navigator.userAgent 2017-12-16 17:52:14.934
#
#                                                value  \
# 0  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...
# 1                            Shockwave Flash 28.0 r0
# 2                            Shockwave Flash 28.0 r0
# 3  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...
# 4                                       Linux x86_64
# 5                                              Gecko
# 6                                                 24
# 7  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...
# 8  {"google_pub_config":"{\"sraConfigs\":{\"2\":{...
# 9  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...
#
#                                            file_name  value_len  \
# 0  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...         68
# 1  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...         23
# 2  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...         23
# 3  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...         68
# 4  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...         12
# 5  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...          5
# 6  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...          2
# 7  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...         68
# 8  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...        129
# 9  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...         68
#
#                                           value_1000
# 0  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...
# 1                            Shockwave Flash 28.0 r0
# 2                            Shockwave Flash 28.0 r0
# 3  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...
# 4                                       Linux x86_64
# 5                                              Gecko
# 6                                                 24
# 7  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...
# 8  {"google_pub_config":"{\"sraConfigs\":{\"2\":{...
# 9  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...

# %%
all_df.dtypes
# Out:
# call_id                    object
# call_stack                 object
# crawl_id                    int64
# func_name                  object
# in_iframe                    bool
# location                   object
# operation                category
# script_col                 object
# script_line                object
# script_loc_eval            object
# script_url                 object
# symbol                     object
# time_stamp         datetime64[ns]
# value                      object
# file_name                  object
# value_len                   int64
# value_1000                 object
# dtype: object

# %%
# %%time
all_df.to_parquet(EXTRACTED_FILE, compression='snappy')
# Out:
# CPU times: user 541 ms, sys: 4.75 ms, total: 546 ms
# Wall time: 561 ms

# %% [markdown]
# ### Process all data

# %%
dfs = []
for file_name in tqdm(index):
    dfs.append(get_df(file_name))
# Out:
# 100%|██████████| 2059735/2059735 [4:13:39<00:00, 135.34it/s]

# %%
'The number of files with bad data is {:,}'.format(len(dfs))
# Out:
# 'The number of files with bad data is 2,059,735'

# %%
dfs[0:10]
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
all_df = pd.concat(dfs, ignore_index=True)

# %%
all_df.location.unique().size
# Out:
# 2468

# %%
all_df.dtypes
# Out:
# arguments                  object
# call_id                    object
# call_stack                 object
# crawl_id                    int64
# file_name                  object
# func_name                  object
# in_iframe                    bool
# location                   object
# operation                category
# script_col                 object
# script_line                object
# script_loc_eval            object
# script_url                 object
# symbol                     object
# time_stamp         datetime64[ns]
# value                      object
# value_1000                 object
# value_len                   int64
# dtype: object

# %%
all_df.to_csv(EXTRACTED_FILE, index=False, compression='gzip')

# %% [markdown]
# Check it all worked out.
#
#
# Note there are still some rows with good script_col script_line because we save for the whole json file that had bad lines.

# %%
df = pd.read_csv(EXTRACTED_FILE)
df.head(10)
# Out:
#   arguments                                            call_id call_stack  \
# 0       NaN  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...        NaN
# 1       NaN  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...        NaN
# 2       NaN  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...        NaN
# 3       NaN  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...        NaN
# 4       NaN  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...        NaN
# 5       NaN  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...        NaN
# 6       NaN  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...        NaN
# 7       NaN  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...        NaN
# 8       NaN  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...        NaN
# 9       NaN  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...        NaN
#
#    crawl_id                                          file_name  \
# 0         1  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...
# 1         1  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...
# 2         1  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...
# 3         1  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...
# 4         1  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...
# 5         1  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...
# 6         1  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...
# 7         1  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...
# 8         1  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...
# 9         1  1_0009022e7df583be8d2fb02720e8ff31e49f1f7d811f...
#
#         func_name  in_iframe           location operation  \
# 0             NaN       True  http://catfly.gr/       get
# 1              Zf       True  http://catfly.gr/       get
# 2              Zf       True  http://catfly.gr/       get
# 3              js       True  http://catfly.gr/       get
# 4              js       True  http://catfly.gr/       get
# 5              js       True  http://catfly.gr/       get
# 6              Cs       True  http://catfly.gr/       get
# 7              mq       True  http://catfly.gr/       get
# 8  likeUsBackShow      False  http://catfly.gr/       get
# 9            $h/<      False  http://catfly.gr/       get
#
#                               script_col script_line script_loc_eval  \
# 0                                  11209           1             NaN
# 1                                  27894           1             NaN
# 2                                  28026           1             NaN
# 3                                 170425           1             NaN
# 4                                 170439           1             NaN
# 5                                 170683           1             NaN
# 6                                 179602           1             NaN
# 7                                 130500           1             NaN
# 8  //cdn.catfly.com/js/script.js?01318aa        http             NaN
# 9                                  48170           1             NaN
#
#                                           script_url  \
# 0  http://pagead2.googlesyndication.com/pagead/js...
# 1  http://pagead2.googlesyndication.com/pagead/js...
# 2  http://pagead2.googlesyndication.com/pagead/js...
# 3  http://pagead2.googlesyndication.com/pagead/js...
# 4  http://pagead2.googlesyndication.com/pagead/js...
# 5  http://pagead2.googlesyndication.com/pagead/js...
# 6  http://pagead2.googlesyndication.com/pagead/js...
# 7  http://pagead2.googlesyndication.com/pagead/js...
# 8                                                NaN
# 9  http://pagead2.googlesyndication.com/pagead/js...
#
#                                               symbol               time_stamp  \
# 0                         window.navigator.userAgent  2017-12-16 17:52:15.130
# 1  window.navigator.plugins[Shockwave Flash].desc...  2017-12-16 17:52:15.149
# 2  window.navigator.plugins[Shockwave Flash].desc...  2017-12-16 17:52:15.149
# 3                         window.navigator.userAgent  2017-12-16 17:52:15.153
# 4                          window.navigator.platform  2017-12-16 17:52:15.154
# 5                           window.navigator.product  2017-12-16 17:52:15.154
# 6                           window.screen.colorDepth  2017-12-16 17:52:15.168
# 7                         window.navigator.userAgent  2017-12-16 17:52:15.207
# 8                                window.localStorage  2017-12-16 17:52:14.701
# 9                         window.navigator.userAgent  2017-12-16 17:52:14.934
#
#                                                value  \
# 0  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...
# 1                            Shockwave Flash 28.0 r0
# 2                            Shockwave Flash 28.0 r0
# 3  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...
# 4                                       Linux x86_64
# 5                                              Gecko
# 6                                                 24
# 7  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...
# 8  {"google_pub_config":"{\"sraConfigs\":{\"2\":{...
# 9  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...
#
#                                           value_1000  value_len
# 0  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...         68
# 1                            Shockwave Flash 28.0 r0         23
# 2                            Shockwave Flash 28.0 r0         23
# 3  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...         68
# 4                                       Linux x86_64         12
# 5                                              Gecko          5
# 6                                                 24          2
# 7  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...         68
# 8  {"google_pub_config":"{\"sraConfigs\":{\"2\":{...        129
# 9  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...         68
