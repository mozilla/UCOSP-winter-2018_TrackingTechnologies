# %%
from __future__ import unicode_literals
from __future__ import division

import json
import pandas as pd
import requests

from ast import literal_eval
from jinja2 import Template
from jsonschema import Draft4Validator
from pyspark.sql.types import TimestampType

pd.options.display.max_columns = None

ORIGINAL_BUCKET_NAME = 'safe-ucosp-2017'
TEST_BUCKET = 'telemetry-test-bucket/birdsarah-test'

N_FILES = 20000

# %%
bad_location_2 = "s3a://{}/bad_{}.parquet".format(TEST_BUCKET, N_FILES)
good_location_2 = "s3a://{}/good_{}.parquet".format(TEST_BUCKET, N_FILES)

# %%
bad_data = spark.read.parquet(bad_location_2).toPandas()

# %%
good_data = spark.read.parquet(good_location_2)

# %%
for val in bad_data.errors:
    print(val)
# Out:
# script_url:  not valid ||
# script_line: webpack not valid ||
# script_col: ///./node_modules/ not valid ||
#
# script_url:  not valid ||
# script_line: webpack not valid ||
# script_col: ///./node_modules/ not valid ||
#
# script_url:  not valid ||
# script_line: webpack not valid ||
# script_col: ///./node_modules/ not valid ||
#
# script_url:  not valid ||
# script_line: webpack not valid ||
# script_col: ///./node_modules/ not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line: webpack not valid ||
# script_col: ///./node_modules/ not valid ||
#
# script_url:  not valid ||
# script_line: webpack not valid ||
# script_col: ///./node_modules/ not valid ||
#
# script_url:  not valid ||
# script_line: webpack not valid ||
# script_col: ///./node_modules/ not valid ||
#
# script_url:  not valid ||
# script_line: webpack not valid ||
# script_col: ///./node_modules/ not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //adv.khan.co.kr/RealMedia/ads/adstream_sx.ads/www.khan.co.kr/newspage not valid ||
#
# script_url:  not valid ||
# script_line: webpack not valid ||
# script_col: ///./node_modules/ not valid ||
#
# script_url:  not valid ||
# script_line: webpack not valid ||
# script_col: ///./node_modules/ not valid ||
#
# script_url:  not valid ||
# script_line: webpack not valid ||
# script_col: ///./node_modules/ not valid ||
#
# script_url:  not valid ||
# script_line: webpack not valid ||
# script_col: ///./node_modules/ not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //static.parastorage.com/unpkg/react-dom not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //static.parastorage.com/unpkg/react-dom not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //static.parastorage.com/unpkg/santa-core-utils not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //static.parastorage.com/unpkg/santa-core-utils not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //static.parastorage.com/unpkg/santa-core-utils not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //static.parastorage.com/unpkg/santa-core-utils not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //static.parastorage.com/unpkg/santa-core-utils not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //static.parastorage.com/unpkg/santa-core-utils not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //static.parastorage.com/unpkg/santa-core-utils not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //static.parastorage.com/unpkg/santa-core-utils not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //static.parastorage.com/unpkg/santa-core-utils not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //static.parastorage.com/unpkg/santa-core-utils not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //static.parastorage.com/unpkg/santa-core-utils not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //static.parastorage.com/unpkg/santa-core-utils not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=video not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513417079141?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462530296?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513418103857?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# ...
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //execution-use.ci360.sas.com/t/s/c/681cceba2200012815576dcc/1513462724613?... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //cdn.jsdelivr.net/g/jquery not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //cdn.jsdelivr.net/g/jquery not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //cdn.jsdelivr.net/g/jquery not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //cdn.jsdelivr.net/g/jquery not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //cdn.jsdelivr.net/g/jquery not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# time_stamp: 2017-12-16T07:04:56+0000 not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: http not valid ||
# script_col: //hdjs.hiido.com/hiido_internal.js?siteid=cr not valid ||
#
# script_url:  not valid ||
# script_line: webpack not valid ||
# script_col: ///./node_modules/ not valid ||
#
# script_url:  not valid ||
# script_line: webpack not valid ||
# script_col: ///./node_modules/ not valid ||
#
# script_url:  not valid ||
# script_line: webpack not valid ||
# script_col: ///./node_modules/ not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# time_stamp: 2017-12-15T22:22:38+0000 not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //enterprise.api-maps.yandex.ru/2.1.56/combine.js?load=5q5j.;. not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //secure.img1-ag.wfcdn.com/lazy_bundler/eng_us/0000000001513380090/init_pag... not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //secure.img1-ag.wfcdn.com/lazy_bundler/eng_us/0000000001513380090/init_pag... not valid ||
#
# script_line: //obj.adman.gr/talos/2017/ledra/13360/index.html?click=http not valid ||
# script_col: //talos.adman.gr/click/ not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //cdn.jsdelivr.net/npm/lazysizes not valid ||
#
# script_url:  not valid ||
# script_line: https not valid ||
# script_col: //unpkg.com/vue not valid ||
#
# script_url:  not valid ||
# script_line:  not valid ||

# %%
bad_count = len(bad_data)
good_count = good_data.count()
print('{:.4%}'.format(bad_count / good_count))
# Out:
# 0.0603%

# %%
good_data.agg({"call_id": "min"}).collect()
# Out:
# [Row(min(call_id)=u'1_0003cdd91a5b81c4d58654ca6c8e18b1c60ed6191c3cb849e37a51af.json__0')]

# %%
good_data.agg({"call_id": "max"}).collect()
# Out:
# [Row(max(call_id)=u'1_fffc766461372954c01be39f51c0ce49b9370e4d07bc892f296a87c9.json__6')]

# %%
http_location = good_data[good_data.location.startswith('http:')]
http_location_count = http_location.count()
https_location = good_data[good_data.location.startswith('https:')]
https_location_count = https_location.count()

# %%
print('{:,} rows'.format(good_count))
print('{:,} http rows'.format(http_location_count))
print('{:,} https rows'.format(https_location_count))
print('Missing: {}'.format(good_count - https_location_count - http_location_count))
print('Proportion https: {:.2%}'.format((https_location_count / good_count)))
# Out:
# 1,138,232 rows
# 400,022 http rows
# 738,210 https rows
# Missing: 0
# Proportion https: 64.86%

# %%
mixed_content = https_location[~https_location.script_url.startswith('https')]

# %%
initial_char = mixed_content.script_url.substr(0, 1)
mixed_content.withColumn('initial_char', initial_char).groupBy('initial_char').count().show()
# Out:
# +------------+-----+
# |initial_char|count|
# +------------+-----+
# |           l|    3|
# |           0|   18|
# |           m|   12|
# |           f|   45|
# |           _|  246|
# |           e|   20|
# |           C|    1|
# |           /|  478|
# |           w|   48|
# |           i|   53|
# |           r|  836|
# |           t|   52|
# |           s|   67|
# +------------+-----+

# %%
good_data.groupBy('operation').count().show()
# Out:
# +---------+------+
# |operation| count|
# +---------+------+
# |      set|145683|
# |     call|264675|
# |      get|727874|
# +---------+------+

# %%
good_data.dtypes
# Out:
# [('argument_0', 'string'),
#  ('argument_1', 'string'),
#  ('argument_2', 'string'),
#  ('argument_3', 'string'),
#  ('argument_4', 'string'),
#  ('argument_5', 'string'),
#  ('argument_6', 'string'),
#  ('argument_7', 'string'),
#  ('argument_8', 'string'),
#  ('arguments', 'string'),
#  ('arguments_n_keys', 'bigint'),
#  ('call_id', 'string'),
#  ('call_stack', 'string'),
#  ('crawl_id', 'bigint'),
#  ('file_name', 'string'),
#  ('func_name', 'string'),
#  ('in_iframe', 'boolean'),
#  ('location', 'string'),
#  ('operation', 'string'),
#  ('script_col', 'string'),
#  ('script_line', 'string'),
#  ('script_loc_eval', 'string'),
#  ('script_url', 'string'),
#  ('symbol', 'string'),
#  ('time_stamp', 'timestamp'),
#  ('value', 'string'),
#  ('value_1000', 'string'),
#  ('value_len', 'int'),
#  ('valid', 'boolean'),
#  ('errors', 'string')]

# %%
good_data.agg({"time_stamp": "min"}).show(1, False)
# Out:
# +-----------------------+
# |min(time_stamp)        |
# +-----------------------+
# |2017-12-15 22:03:00.695|
# +-----------------------+

# %%
good_data.agg({"time_stamp": "max"}).show(1, False)
# Out:
# +-----------------------+
# |max(time_stamp)        |
# +-----------------------+
# |2017-12-17 01:26:50.584|
# +-----------------------+

# %% [markdown]
# ### Turns out there are some acceptable timestamps that we've rejected

# %%
time_stamp_rejects = bad_data[bad_data.errors.str.contains("time_stamp")]
time_stamp_rejects.head(2)
# Out:
#     argument_0 argument_1 argument_2 argument_3 argument_4 argument_5  \
# 528
# 529
#
#     argument_6 argument_7 argument_8 arguments arguments_n_keys  \
# 528                                                        None
# 529                                                        None
#
#                                                call_id call_stack  crawl_id  \
# 528  1_81c7ac09151998d58700669645e2dd69891532b068dd...                    1
# 529  1_81c7ac09151998d58700669645e2dd69891532b068dd...                    1
#
#                                              file_name func_name in_iframe  \
# 528  1_81c7ac09151998d58700669645e2dd69891532b068dd...               False
# 529  1_81c7ac09151998d58700669645e2dd69891532b068dd...               False
#
#                                             location operation script_col  \
# 528  https://www.tripadvisor.co.uk/BusinessAdvantage       get         77
# 529  https://www.tripadvisor.co.uk/BusinessAdvantage       get        140
#
#     script_line script_loc_eval  \
# 528          16
# 529          16
#
#                                             script_url  \
# 528  https://static.tacdn.com/js3/tripadvisor-c-v23...
# 529  https://static.tacdn.com/js3/tripadvisor-c-v23...
#
#                          symbol                time_stamp  \
# 528  window.navigator.userAgent  2017-12-16T07:04:56+0000
# 529   window.navigator.platform  2017-12-16T07:04:56+0000
#
#                                                  value value_1000 value_len  \
# 528  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...
# 529                                       Linux x86_64
#
#      valid                                             errors
# 528  False  time_stamp: 2017-12-16T07:04:56+0000 not valid...
# 529  False  time_stamp: 2017-12-16T07:04:56+0000 not valid...

# %%
time_stamp_rejects.file_name.unique()
# Out:
# array([u'1_81c7ac09151998d58700669645e2dd69891532b068dd552bf77e6bfb.json',
#        u'1_678ed8d87c1e36a2fa5f429400a62161761658737c49bb3765ad7d50.json'], dtype=object)

# %%
symbol_counts = pd.read_csv('symbol_counts.csv', names=['symbol', 'count'])
with open('raw_data_schema.template', 'r') as f:
    schema_template = Template(f.read())
schema = literal_eval(
    schema_template.render(
        list_of_symbols=list(symbol_counts.symbol.values)
    )
)

def get_rows_from_s3(file_name):
    file_url = 'https://s3.amazonaws.com/{}/{}'.format(ORIGINAL_BUCKET_NAME, file_name)
    response = requests.get(file_url)
    assert response.status_code == 200
    fix_data = lambda x:  "[" + x[1:-1] + "]"
    data = fix_data(response.content)
    rows = json.loads(data)
    return rows

def validate_and_process_file(file_name):
    validator = Draft4Validator(schema)
    rows = get_rows_from_s3(file_name)

    for i, row in enumerate(rows):
        errors = ''
        valid = validator.is_valid(row)
        
        # If data was not valid, get the error information
        if valid is False:
            for error in validator.iter_errors(row):
                bad_value_truncated = error.instance[:75] + (error.instance[75:] and '...')
                errors += '{}: {} not valid ||\n'.format(
                    error.path[0], bad_value_truncated
                )
        
        row['file_name'] = '{}'.format(file_name)
        row['call_id'] = '{}__{}'.format(file_name, i)
        row['valid'] = valid
        row['errors'] = errors
        
        if valid is True:
            row = process_arguments(row)
        
    return rows

# %%
rows = validate_and_process_file('1_81c7ac09151998d58700669645e2dd69891532b068dd552bf77e6bfb.json')

# %%
rows[2]
# Out:
# {u'arguments': u'{}',
#  u'arguments_n_keys': 0,
#  u'call_id': u'1_81c7ac09151998d58700669645e2dd69891532b068dd552bf77e6bfb.json__2',
#  u'call_stack': u'',
#  u'crawl_id': 1,
#  u'errors': u'',
#  u'file_name': u'1_81c7ac09151998d58700669645e2dd69891532b068dd552bf77e6bfb.json',
#  u'func_name': u'version<',
#  u'in_iframe': False,
#  u'location': u'https://www.tripadvisor.co.uk/BusinessAdvantage',
#  u'operation': u'get',
#  u'script_col': u'1543',
#  u'script_line': u'10',
#  u'script_loc_eval': u'',
#  u'script_url': u'https://static.tacdn.com/js3/mootools-c-v22847647807b.js',
#  u'symbol': u'window.navigator.plugins[Shockwave Flash].description',
#  u'time_stamp': u'2017-12-16T07:04:56.069Z',
#  u'valid': True,
#  u'value': u'Shockwave Flash 28.0 r0'}

# %%
rows[3]
# Out:
# {u'arguments': u'{}',
#  u'arguments_n_keys': 0,
#  u'call_id': u'1_81c7ac09151998d58700669645e2dd69891532b068dd552bf77e6bfb.json__3',
#  u'call_stack': u'',
#  u'crawl_id': 1,
#  u'errors': u'',
#  u'file_name': u'1_81c7ac09151998d58700669645e2dd69891532b068dd552bf77e6bfb.json',
#  u'func_name': u'',
#  u'in_iframe': False,
#  u'location': u'https://www.tripadvisor.co.uk/BusinessAdvantage',
#  u'operation': u'get',
#  u'script_col': u'77',
#  u'script_line': u'16',
#  u'script_loc_eval': u'',
#  u'script_url': u'https://static.tacdn.com/js3/tripadvisor-c-v23806297793b.js',
#  u'symbol': u'window.navigator.userAgent',
#  u'time_stamp': u'2017-12-16T07:04:56+0000',
#  u'valid': True,
#  u'value': u'Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'}

# %%
fileRDD = sc.parallelize(['1_81c7ac09151998d58700669645e2dd69891532b068dd552bf77e6bfb.json'])
validated_rows = fileRDD.flatMap(validate_and_process_file)
validated_df = validated_rows.map(lambda x: (x.get('time_stamp', ""),)).toDF(('time_stamp',))
validated_df = validated_df.withColumn('time_stamp', validated_df.time_stamp.cast(TimestampType()))
validated_df.show(100, False)
# Out:
# +-----------------------+
# |time_stamp             |
# +-----------------------+
# |2017-12-16 07:04:56.067|
# |2017-12-16 07:04:56.068|
# |2017-12-16 07:04:56.069|
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56    |
# |2017-12-16 07:04:56.55 |
# |2017-12-16 07:04:56.552|
# |2017-12-16 07:04:56.597|
# |2017-12-16 07:04:56.598|
# |2017-12-16 07:04:56.758|
# |2017-12-16 07:04:56.793|
# |2017-12-16 07:04:56.794|
# |2017-12-16 07:04:56.795|
# |2017-12-16 07:04:56.797|
# |2017-12-16 07:04:56.819|
# |2017-12-16 07:04:56.819|
# |2017-12-16 07:04:56.819|
# |2017-12-16 07:04:56.82 |
# |2017-12-16 07:04:56.82 |
# |2017-12-16 07:04:56.821|
# |2017-12-16 07:04:56.821|
# |2017-12-16 07:04:56.887|
# |2017-12-16 07:04:56.888|
# |2017-12-16 07:04:56.888|
# |2017-12-16 07:04:56.889|
# |2017-12-16 07:04:56.889|
# |2017-12-16 07:04:56.891|
# |2017-12-16 07:04:56.891|
# |2017-12-16 07:04:56.891|
# |2017-12-16 07:04:56.892|
# |2017-12-16 07:04:56.892|
# |2017-12-16 07:04:56.892|
# |2017-12-16 07:04:56.893|
# |2017-12-16 07:04:56.893|
# |2017-12-16 07:04:56.893|
# |2017-12-16 07:04:56.893|
# |2017-12-16 07:04:56.894|
# |2017-12-16 07:04:56.894|
# |2017-12-16 07:04:56.894|
# |2017-12-16 07:04:56.894|
# |2017-12-16 07:04:56.894|
# |2017-12-16 07:04:56.895|
# |2017-12-16 07:04:56.895|
# |2017-12-16 07:04:56.895|
# |2017-12-16 07:04:56.895|
# |2017-12-16 07:04:56.895|
# |2017-12-16 07:04:56.896|
# |2017-12-16 07:04:56.896|
# +-----------------------+

# %% [markdown]
# ### Time to process
#
# 14 min for 20,000 rows - 8 workers

# %%
multiplier = 2059735 / 20000
multiplier
# Out:
# 102.98675

# %%
estimated_time_to_complete = (14 * multiplier) / 60
'{:.0f} hours with 8 workers'.format(estimated_time_to_complete)
# Out:
# u'24 hours with 8 workers'

# %%
'{:.0f} hours with 30 workers'.format(estimated_time_to_complete / (30/8))
# Out:
# u'6 hours with 30 workers'

# %%
good_data.dtypes
# Out:
# [('argument_0', 'string'),
#  ('argument_1', 'string'),
#  ('argument_2', 'string'),
#  ('argument_3', 'string'),
#  ('argument_4', 'string'),
#  ('argument_5', 'string'),
#  ('argument_6', 'string'),
#  ('argument_7', 'string'),
#  ('argument_8', 'string'),
#  ('arguments', 'string'),
#  ('arguments_n_keys', 'bigint'),
#  ('call_id', 'string'),
#  ('call_stack', 'string'),
#  ('crawl_id', 'bigint'),
#  ('file_name', 'string'),
#  ('func_name', 'string'),
#  ('in_iframe', 'boolean'),
#  ('location', 'string'),
#  ('operation', 'string'),
#  ('script_col', 'string'),
#  ('script_line', 'string'),
#  ('script_loc_eval', 'string'),
#  ('script_url', 'string'),
#  ('symbol', 'string'),
#  ('time_stamp', 'timestamp'),
#  ('value', 'string'),
#  ('value_1000', 'string'),
#  ('value_len', 'int'),
#  ('valid', 'boolean'),
#  ('errors', 'string')]

# %%
good_data.agg({"arguments_n_keys": "max"}).show(1, False)
# Out:
# +---------------------+
# |max(arguments_n_keys)|
# +---------------------+
# |6                    |
# +---------------------+

# %%
max_keys = good_data[good_data.arguments_n_keys == 6].toPandas()

# %%
max_keys
# Out:
#               argument_0          argument_1          argument_2  \
# 0                     50                  50                  50
# 1                    100                  50                  50
# 2                     75                 100                  50
# 3                     75                  75                  75
# 4                     75                  75                  25
# 5                    190                 -40                 100
# 6                      0                   0                 0.5
# 7                      0                   0                 0.5
# 8                      0                   0                 0.5
# 9                      0                   0                 0.5
# 10                     0                   0                 0.5
# 11                     0                   0                 0.5
# 12                     0                   0                 0.5
# 13                     0                   0                 0.5
# 14                     0                   0                 0.5
# 15                     0                   0                 0.5
# 16                     0                   0                 0.5
# 17                     0                   0                 0.5
# 18                     0                   0                 0.5
# 19                     0                   0                 0.5
# 20                     0                   0                 0.5
# 21                     0                   0                 0.5
# 22                     0                   0                 0.5
# 23                     0                   0                 0.5
# 24                     0                   0                 0.5
# 25                     0                   0                 0.5
# 26                     0                   0                 0.5
# 27                     0                   0                 0.5
# 28                     0                   0                 0.5
# 29                     0                   0                 0.5
# ...                  ...                 ...                 ...
# 5505   84.64775402098894  196.81592886336148   186.1316818278283
# 5506   72.67305576242507    84.9425258114934    65.2983826585114
# 5507   99.78121779859066   43.84683291427791                   0
# 5508   92.48007093556225  143.50589658133686                   0
# 5509  119.67781600542367  169.69978888519108                   0
# 5510   77.31457282789052   151.0911524295807                   0
# 5511   136.9108528830111   129.0849715936929                   0
# 5512   94.77118658833206    86.7674290202558                   0
# 5513  140.83859999664128  193.86865813285112   7.880851300433278
# 5514   46.29692663438618   96.02760053239763  18.071448197588325
# 5515    74.3725301232189  145.88332064449787  117.69094513729215
# 5516   42.94575611129403   170.8670654334128                   0
# 5517   96.63917194120586   34.09094577655196                   0
# 5518   83.46835416741669   187.6883869059384                   0
# 5519                  80                  10                  20
# 5520                  50                  50                  50
# 5521                 100                  50                  50
# 5522                  75                 100                  50
# 5523                  75                  75                  75
# 5524                  75                  75                  25
# 5525                  50                  50                  50
# 5526                 100                  50                  50
# 5527                  75                 100                  50
# 5528                  75                  75                  75
# 5529                  75                  75                  25
# 5530                  50                  50                  50
# 5531                 100                  50                  50
# 5532                  75                 100                  50
# 5533                  75                  75                  75
# 5534                  75                  75                  25
#
#               argument_3          argument_4          argument_5 argument_6  \
# 0                      0   6.283185307179586                true
# 1                      0   6.283185307179586                true
# 2                      0   6.283185307179586                true
# 3                      0   6.283185307179586                true
# 4                      0   6.283185307179586                true
# 5                     50                 100                  50
# 6                      0   6.283185307179586                true
# 7                      0   6.283185307179586                true
# 8                      0   6.283185307179586                true
# 9                      0   6.283185307179586                true
# 10                     0   6.283185307179586                true
# 11                     0   6.283185307179586                true
# 12                     0   6.283185307179586                true
# 13                     0   6.283185307179586                true
# 14                     0   6.283185307179586                true
# 15                     0   6.283185307179586                true
# 16                     0   6.283185307179586                true
# 17                     0   6.283185307179586                true
# 18                     0  6.2831854820251465                   1
# 19                     0  6.2831854820251465                   1
# 20                     0  6.2831854820251465                   1
# 21                     0  6.2831854820251465                   1
# 22                     0  6.2831854820251465                   1
# 23                     0  6.2831854820251465                   1
# 24                     0  6.2831854820251465                   1
# 25                     0  6.2831854820251465                   1
# 26                     0  6.2831854820251465                   1
# 27                     0  6.2831854820251465                   1
# 28                     0  6.2831854820251465                   1
# 29                     0  6.2831854820251465                   1
# ...                  ...                 ...                 ...        ...
# 5505   143.6184089165181   74.19190420769155   86.54646566137671
# 5506  197.75180481374264  20.533224707469344   135.3440408129245
# 5507  187.30061198584735   86.71133099123836                 400
# 5508   141.0011308733374  123.11494695022702                 400
# 5509  55.800757091492414  187.47618519701064                 400
# 5510   158.7808130774647  175.85995625704527                 400
# 5511  193.59733695164323   79.43848483264446                 400
# 5512  107.33789433725178  110.03469391725957                 400
# 5513  108.51749181747437   194.3657205440104  189.48649396188557
# 5514   57.38146863877773   32.03057209029794   121.3908364996314
# 5515   84.56234405748546  107.93095245026052   77.78915576636791
# 5516   96.81937000714242  18.408052576705813                 400
# 5517   155.8480861596763   61.02013890631497                 400
# 5518  141.01022300310433   64.86522327177227                 400
# 5519                   0   3.141592653589793               false
# 5520                   0   6.283185307179586                true
# 5521                   0   6.283185307179586                true
# 5522                   0   6.283185307179586                true
# 5523                   0   6.283185307179586                true
# 5524                   0   6.283185307179586                true
# 5525                   0   6.283185307179586                true
# 5526                   0   6.283185307179586                true
# 5527                   0   6.283185307179586                true
# 5528                   0   6.283185307179586                true
# 5529                   0   6.283185307179586                true
# 5530                   0   6.283185307179586                true
# 5531                   0   6.283185307179586                true
# 5532                   0   6.283185307179586                true
# 5533                   0   6.283185307179586                true
# 5534                   0   6.283185307179586                true
#
#      argument_7 argument_8                                          arguments  \
# 0                           {"0":50,"1":50,"2":50,"3":0,"4":6.283185307179...
# 1                           {"0":100,"1":50,"2":50,"3":0,"4":6.28318530717...
# 2                           {"0":75,"1":100,"2":50,"3":0,"4":6.28318530717...
# 3                           {"0":75,"1":75,"2":75,"3":0,"4":6.283185307179...
# 4                           {"0":75,"1":75,"2":25,"3":0,"4":6.283185307179...
# 5                             {"0":190,"1":-40,"2":100,"3":50,"4":100,"5":50}
# 6                           {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831853071795...
# 7                           {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831853071795...
# 8                           {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831853071795...
# 9                           {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831853071795...
# 10                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831853071795...
# 11                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831853071795...
# 12                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831853071795...
# 13                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831853071795...
# 14                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831853071795...
# 15                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831853071795...
# 16                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831853071795...
# 17                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831853071795...
# 18                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831854820251...
# 19                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831854820251...
# 20                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831854820251...
# 21                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831854820251...
# 22                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831854820251...
# 23                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831854820251...
# 24                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831854820251...
# 25                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831854820251...
# 26                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831854820251...
# 27                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831854820251...
# 28                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831854820251...
# 29                          {"0":0,"1":0,"2":0.5,"3":0,"4":6.2831854820251...
# ...         ...        ...                                                ...
# 5505                        {"0":84.64775402098894,"1":196.81592886336148,...
# 5506                        {"0":72.67305576242507,"1":84.9425258114934,"2...
# 5507                        {"0":99.78121779859066,"1":43.84683291427791,"...
# 5508                        {"0":92.48007093556225,"1":143.50589658133686,...
# 5509                        {"0":119.67781600542367,"1":169.69978888519108...
# 5510                        {"0":77.31457282789052,"1":151.0911524295807,"...
# 5511                        {"0":136.9108528830111,"1":129.0849715936929,"...
# 5512                        {"0":94.77118658833206,"1":86.7674290202558,"2...
# 5513                        {"0":140.83859999664128,"1":193.86865813285112...
# 5514                        {"0":46.29692663438618,"1":96.02760053239763,"...
# 5515                        {"0":74.3725301232189,"1":145.88332064449787,"...
# 5516                        {"0":42.94575611129403,"1":170.8670654334128,"...
# 5517                        {"0":96.63917194120586,"1":34.09094577655196,"...
# 5518                        {"0":83.46835416741669,"1":187.6883869059384,"...
# 5519                        {"0":80,"1":10,"2":20,"3":0,"4":3.141592653589...
# 5520                        {"0":50,"1":50,"2":50,"3":0,"4":6.283185307179...
# 5521                        {"0":100,"1":50,"2":50,"3":0,"4":6.28318530717...
# 5522                        {"0":75,"1":100,"2":50,"3":0,"4":6.28318530717...
# 5523                        {"0":75,"1":75,"2":75,"3":0,"4":6.283185307179...
# 5524                        {"0":75,"1":75,"2":25,"3":0,"4":6.283185307179...
# 5525                        {"0":50,"1":50,"2":50,"3":0,"4":6.283185307179...
# 5526                        {"0":100,"1":50,"2":50,"3":0,"4":6.28318530717...
# 5527                        {"0":75,"1":100,"2":50,"3":0,"4":6.28318530717...
# 5528                        {"0":75,"1":75,"2":75,"3":0,"4":6.283185307179...
# 5529                        {"0":75,"1":75,"2":25,"3":0,"4":6.283185307179...
# 5530                        {"0":50,"1":50,"2":50,"3":0,"4":6.283185307179...
# 5531                        {"0":100,"1":50,"2":50,"3":0,"4":6.28318530717...
# 5532                        {"0":75,"1":100,"2":50,"3":0,"4":6.28318530717...
# 5533                        {"0":75,"1":75,"2":75,"3":0,"4":6.283185307179...
# 5534                        {"0":75,"1":75,"2":25,"3":0,"4":6.283185307179...
#
#       arguments_n_keys                                            call_id  \
# 0                    6  1_294a4c2b123af5030649020e47d949319dc240aca847...
# 1                    6  1_294a4c2b123af5030649020e47d949319dc240aca847...
# 2                    6  1_294a4c2b123af5030649020e47d949319dc240aca847...
# 3                    6  1_294a4c2b123af5030649020e47d949319dc240aca847...
# 4                    6  1_294a4c2b123af5030649020e47d949319dc240aca847...
# 5                    6  1_381930ffb27a30dd209881b2ba58fff64bc0e9f216bf...
# 6                    6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 7                    6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 8                    6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 9                    6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 10                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 11                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 12                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 13                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 14                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 15                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 16                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 17                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 18                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 19                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 20                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 21                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 22                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 23                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 24                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 25                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 26                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 27                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 28                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 29                   6  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# ...                ...                                                ...
# 5505                 6  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5506                 6  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5507                 6  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5508                 6  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5509                 6  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5510                 6  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5511                 6  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5512                 6  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5513                 6  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5514                 6  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5515                 6  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5516                 6  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5517                 6  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5518                 6  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5519                 6  1_0eea42797501111f11c8658fc58704957cb9cbb7e013...
# 5520                 6  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5521                 6  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5522                 6  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5523                 6  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5524                 6  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5525                 6  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5526                 6  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5527                 6  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5528                 6  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5529                 6  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5530                 6  1_3f9be144934ec4a61e0c2fdad191949af54fc1b3ac2d...
# 5531                 6  1_3f9be144934ec4a61e0c2fdad191949af54fc1b3ac2d...
# 5532                 6  1_3f9be144934ec4a61e0c2fdad191949af54fc1b3ac2d...
# 5533                 6  1_3f9be144934ec4a61e0c2fdad191949af54fc1b3ac2d...
# 5534                 6  1_3f9be144934ec4a61e0c2fdad191949af54fc1b3ac2d...
#
#      call_stack  crawl_id                                          file_name  \
# 0                       1  1_294a4c2b123af5030649020e47d949319dc240aca847...
# 1                       1  1_294a4c2b123af5030649020e47d949319dc240aca847...
# 2                       1  1_294a4c2b123af5030649020e47d949319dc240aca847...
# 3                       1  1_294a4c2b123af5030649020e47d949319dc240aca847...
# 4                       1  1_294a4c2b123af5030649020e47d949319dc240aca847...
# 5                       1  1_381930ffb27a30dd209881b2ba58fff64bc0e9f216bf...
# 6                       1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 7                       1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 8                       1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 9                       1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 10                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 11                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 12                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 13                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 14                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 15                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 16                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 17                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 18                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 19                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 20                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 21                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 22                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 23                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 24                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 25                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 26                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 27                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 28                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# 29                      1  1_45ed8d8e5d7ae44f7df637a8065eeec682a0366fe90b...
# ...         ...       ...                                                ...
# 5505                    1  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5506                    1  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5507                    1  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5508                    1  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5509                    1  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5510                    1  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5511                    1  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5512                    1  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5513                    1  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5514                    1  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5515                    1  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5516                    1  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5517                    1  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5518                    1  1_495f66899836a2b66eb6016ed8040cfb1a7a8fd4e709...
# 5519                    1  1_0eea42797501111f11c8658fc58704957cb9cbb7e013...
# 5520                    1  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5521                    1  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5522                    1  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5523                    1  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5524                    1  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5525                    1  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5526                    1  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5527                    1  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5528                    1  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5529                    1  1_62362d2e30718f0b5ae6e5cf5a09a6d02f05dab973fe...
# 5530                    1  1_3f9be144934ec4a61e0c2fdad191949af54fc1b3ac2d...
# 5531                    1  1_3f9be144934ec4a61e0c2fdad191949af54fc1b3ac2d...
# 5532                    1  1_3f9be144934ec4a61e0c2fdad191949af54fc1b3ac2d...
# 5533                    1  1_3f9be144934ec4a61e0c2fdad191949af54fc1b3ac2d...
# 5534                    1  1_3f9be144934ec4a61e0c2fdad191949af54fc1b3ac2d...
#
#                              func_name in_iframe  \
# 0              e.prototype.getCanvasFp     False
# 1              e.prototype.getCanvasFp     False
# 2              e.prototype.getCanvasFp     False
# 3              e.prototype.getCanvasFp     False
# 4              e.prototype.getCanvasFp     False
# 5                                 T/q<     False
# 6                             _[E].arc     False
# 7                             _[E].arc     False
# 8                             _[E].arc     False
# 9                             _[E].arc     False
# 10                            _[E].arc     False
# 11                            _[E].arc     False
# 12                            _[E].arc     False
# 13                            _[E].arc     False
# 14                            _[E].arc     False
# 15                            _[E].arc     False
# 16                            _[E].arc     False
# 17                            _[E].arc     False
# 18                    _[E].rebuildPath     False
# 19                    _[E].rebuildPath     False
# 20                    _[E].rebuildPath     False
# 21                    _[E].rebuildPath     False
# 22                    _[E].rebuildPath     False
# 23                    _[E].rebuildPath     False
# 24                    _[E].rebuildPath     False
# 25                    _[E].rebuildPath     False
# 26                    _[E].rebuildPath     False
# 27                    _[E].rebuildPath     False
# 28                    _[E].rebuildPath     False
# 29                    _[E].rebuildPath     False
# ...                                ...       ...
# 5505          a/h.prototype.drawBezier     False
# 5506          a/h.prototype.drawBezier     False
# 5507  a/h.prototype.makeRadialGradient     False
# 5508  a/h.prototype.makeRadialGradient     False
# 5509  a/h.prototype.makeRadialGradient     False
# 5510  a/h.prototype.makeRadialGradient     False
# 5511  a/h.prototype.makeRadialGradient     False
# 5512  a/h.prototype.makeRadialGradient     False
# 5513          a/h.prototype.drawBezier     False
# 5514          a/h.prototype.drawBezier     False
# 5515          a/h.prototype.drawBezier     False
# 5516  a/h.prototype.makeRadialGradient     False
# 5517  a/h.prototype.makeRadialGradient     False
# 5518  a/h.prototype.makeRadialGradient     False
# 5519                       e[_ac[580]]     False
# 5520        [5]</r.exports.getCanvasFp      True
# 5521        [5]</r.exports.getCanvasFp      True
# 5522        [5]</r.exports.getCanvasFp      True
# 5523        [5]</r.exports.getCanvasFp      True
# 5524        [5]</r.exports.getCanvasFp      True
# 5525        [5]</r.exports.getCanvasFp      True
# 5526        [5]</r.exports.getCanvasFp      True
# 5527        [5]</r.exports.getCanvasFp      True
# 5528        [5]</r.exports.getCanvasFp      True
# 5529        [5]</r.exports.getCanvasFp      True
# 5530           a.prototype.getCanvasFp     False
# 5531           a.prototype.getCanvasFp     False
# 5532           a.prototype.getCanvasFp     False
# 5533           a.prototype.getCanvasFp     False
# 5534           a.prototype.getCanvasFp     False
#
#                                                location operation script_col  \
# 0                   https://ck101.com/forum-3689-1.html      call      17893
# 1                   https://ck101.com/forum-3689-1.html      call      17990
# 2                   https://ck101.com/forum-3689-1.html      call      18088
# 3                   https://ck101.com/forum-3689-1.html      call      18172
# 4                   https://ck101.com/forum-3689-1.html      call      18203
# 5     http://igg-games.com/donate-share-game-support...      call        192
# 6                       http://koubei.checheng.com/1868      call      20952
# 7                       http://koubei.checheng.com/1868      call      20952
# 8                       http://koubei.checheng.com/1868      call      20952
# 9                       http://koubei.checheng.com/1868      call      20952
# 10                      http://koubei.checheng.com/1868      call      20952
# 11                      http://koubei.checheng.com/1868      call      20952
# 12                      http://koubei.checheng.com/1868      call      20952
# 13                      http://koubei.checheng.com/1868      call      20952
# 14                      http://koubei.checheng.com/1868      call      20952
# 15                      http://koubei.checheng.com/1868      call      20952
# 16                      http://koubei.checheng.com/1868      call      20952
# 17                      http://koubei.checheng.com/1868      call      20952
# 18                      http://koubei.checheng.com/1868      call      25316
# 19                      http://koubei.checheng.com/1868      call      25316
# 20                      http://koubei.checheng.com/1868      call      25316
# 21                      http://koubei.checheng.com/1868      call      25316
# 22                      http://koubei.checheng.com/1868      call      25316
# 23                      http://koubei.checheng.com/1868      call      25316
# 24                      http://koubei.checheng.com/1868      call      25316
# 25                      http://koubei.checheng.com/1868      call      25316
# 26                      http://koubei.checheng.com/1868      call      25316
# 27                      http://koubei.checheng.com/1868      call      25316
# 28                      http://koubei.checheng.com/1868      call      25316
# 29                      http://koubei.checheng.com/1868      call      25316
# ...                                                 ...       ...        ...
# 5505              https://www.facebook.com/reporterlive      call       1968
# 5506              https://www.facebook.com/reporterlive      call       2086
# 5507              https://www.facebook.com/reporterlive      call       2676
# 5508              https://www.facebook.com/reporterlive      call       2676
# 5509              https://www.facebook.com/reporterlive      call       2676
# 5510              https://www.facebook.com/reporterlive      call       2676
# 5511              https://www.facebook.com/reporterlive      call       2676
# 5512              https://www.facebook.com/reporterlive      call       2676
# 5513              https://www.facebook.com/reporterlive      call       1850
# 5514              https://www.facebook.com/reporterlive      call       1968
# 5515              https://www.facebook.com/reporterlive      call       2086
# 5516              https://www.facebook.com/reporterlive      call       2676
# 5517              https://www.facebook.com/reporterlive      call       2676
# 5518              https://www.facebook.com/reporterlive      call       2676
# 5519  https://www.gucci.com/ca/en/st/capsule/gg-marm...      call      51252
# 5520    https://www.carsales.com.au/cars/ute-bodystyle/      call        166
# 5521    https://www.carsales.com.au/cars/ute-bodystyle/      call        263
# 5522    https://www.carsales.com.au/cars/ute-bodystyle/      call        361
# 5523    https://www.carsales.com.au/cars/ute-bodystyle/      call        445
# 5524    https://www.carsales.com.au/cars/ute-bodystyle/      call        476
# 5525    https://www.carsales.com.au/cars/ute-bodystyle/      call        166
# 5526    https://www.carsales.com.au/cars/ute-bodystyle/      call        263
# 5527    https://www.carsales.com.au/cars/ute-bodystyle/      call        361
# 5528    https://www.carsales.com.au/cars/ute-bodystyle/      call        445
# 5529    https://www.carsales.com.au/cars/ute-bodystyle/      call        476
# 5530  https://www.elo7.com.br/login.do?redirectAfter...      call      17440
# 5531  https://www.elo7.com.br/login.do?redirectAfter...      call      17537
# 5532  https://www.elo7.com.br/login.do?redirectAfter...      call      17635
# 5533  https://www.elo7.com.br/login.do?redirectAfter...      call      17719
# 5534  https://www.elo7.com.br/login.do?redirectAfter...      call      17750
#
#      script_line script_loc_eval  \
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# 5             27
# 6              4
# 7              4
# 8              4
# 9              4
# 10             4
# 11             4
# 12             4
# 13             4
# 14             4
# 15             4
# 16             4
# 17             4
# 18             4
# 19             4
# 20             4
# 21             4
# 22             4
# 23             4
# 24             4
# 25             4
# 26             4
# 27             4
# 28             4
# 29             4
# ...          ...             ...
# 5505          21
# 5506          21
# 5507          21
# 5508          21
# 5509          21
# 5510          21
# 5511          21
# 5512          21
# 5513          21
# 5514          21
# 5515          21
# 5516          21
# 5517          21
# 5518          21
# 5519           1
# 5520          26
# 5521          26
# 5522          26
# 5523          26
# 5524          26
# 5525          26
# 5526          26
# 5527          26
# 5528          26
# 5529          26
# 5530           1
# 5531           1
# 5532           1
# 5533           1
# 5534           1
#
#                                              script_url  \
# 0                https://a.breaktime.com.tw/js/au-ac.js
# 1                https://a.breaktime.com.tw/js/au-ac.js
# 2                https://a.breaktime.com.tw/js/au-ac.js
# 3                https://a.breaktime.com.tw/js/au-ac.js
# 4                https://a.breaktime.com.tw/js/au-ac.js
# 5                                    http://c.adsco.re/
# 6     http://static.checheng.com/common/car/js/echar...
# 7     http://static.checheng.com/common/car/js/echar...
# 8     http://static.checheng.com/common/car/js/echar...
# 9     http://static.checheng.com/common/car/js/echar...
# 10    http://static.checheng.com/common/car/js/echar...
# 11    http://static.checheng.com/common/car/js/echar...
# 12    http://static.checheng.com/common/car/js/echar...
# 13    http://static.checheng.com/common/car/js/echar...
# 14    http://static.checheng.com/common/car/js/echar...
# 15    http://static.checheng.com/common/car/js/echar...
# 16    http://static.checheng.com/common/car/js/echar...
# 17    http://static.checheng.com/common/car/js/echar...
# 18    http://static.checheng.com/common/car/js/echar...
# 19    http://static.checheng.com/common/car/js/echar...
# 20    http://static.checheng.com/common/car/js/echar...
# 21    http://static.checheng.com/common/car/js/echar...
# 22    http://static.checheng.com/common/car/js/echar...
# 23    http://static.checheng.com/common/car/js/echar...
# 24    http://static.checheng.com/common/car/js/echar...
# 25    http://static.checheng.com/common/car/js/echar...
# 26    http://static.checheng.com/common/car/js/echar...
# 27    http://static.checheng.com/common/car/js/echar...
# 28    http://static.checheng.com/common/car/js/echar...
# 29    http://static.checheng.com/common/car/js/echar...
# ...                                                 ...
# 5505  https://static.xx.fbcdn.net/rsrc.php/v3iUNm4/y...
# 5506  https://static.xx.fbcdn.net/rsrc.php/v3iUNm4/y...
# 5507  https://static.xx.fbcdn.net/rsrc.php/v3iUNm4/y...
# 5508  https://static.xx.fbcdn.net/rsrc.php/v3iUNm4/y...
# 5509  https://static.xx.fbcdn.net/rsrc.php/v3iUNm4/y...
# 5510  https://static.xx.fbcdn.net/rsrc.php/v3iUNm4/y...
# 5511  https://static.xx.fbcdn.net/rsrc.php/v3iUNm4/y...
# 5512  https://static.xx.fbcdn.net/rsrc.php/v3iUNm4/y...
# 5513  https://static.xx.fbcdn.net/rsrc.php/v3iUNm4/y...
# 5514  https://static.xx.fbcdn.net/rsrc.php/v3iUNm4/y...
# 5515  https://static.xx.fbcdn.net/rsrc.php/v3iUNm4/y...
# 5516  https://static.xx.fbcdn.net/rsrc.php/v3iUNm4/y...
# 5517  https://static.xx.fbcdn.net/rsrc.php/v3iUNm4/y...
# 5518  https://static.xx.fbcdn.net/rsrc.php/v3iUNm4/y...
# 5519                 https://www.gucci.com/_bm/async.js
# 5520                https://z.moatads.com/px2/client.js
# 5521                https://z.moatads.com/px2/client.js
# 5522                https://z.moatads.com/px2/client.js
# 5523                https://z.moatads.com/px2/client.js
# 5524                https://z.moatads.com/px2/client.js
# 5525                https://z.moatads.com/px2/client.js
# 5526                https://z.moatads.com/px2/client.js
# 5527                https://z.moatads.com/px2/client.js
# 5528                https://z.moatads.com/px2/client.js
# 5529                https://z.moatads.com/px2/client.js
# 5530  https://images.elo7.com.br/assets/v3/common/js...
# 5531  https://images.elo7.com.br/assets/v3/common/js...
# 5532  https://images.elo7.com.br/assets/v3/common/js...
# 5533  https://images.elo7.com.br/assets/v3/common/js...
# 5534  https://images.elo7.com.br/assets/v3/common/js...
#
#                                              symbol              time_stamp  \
# 0                      CanvasRenderingContext2D.arc 2017-12-16 23:57:03.471
# 1                      CanvasRenderingContext2D.arc 2017-12-16 23:57:03.474
# 2                      CanvasRenderingContext2D.arc 2017-12-16 23:57:03.474
# 3                      CanvasRenderingContext2D.arc 2017-12-16 23:57:03.475
# 4                      CanvasRenderingContext2D.arc 2017-12-16 23:57:03.475
# 5            CanvasRenderingContext2D.bezierCurveTo 2017-12-15 23:31:59.464
# 6                      CanvasRenderingContext2D.arc 2017-12-16 15:49:50.120
# 7                      CanvasRenderingContext2D.arc 2017-12-16 15:49:50.125
# 8                      CanvasRenderingContext2D.arc 2017-12-16 15:49:50.126
# 9                      CanvasRenderingContext2D.arc 2017-12-16 15:49:50.128
# 10                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.130
# 11                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.132
# 12                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.253
# 13                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.254
# 14                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.254
# 15                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.255
# 16                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.256
# 17                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.260
# 18                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.343
# 19                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.343
# 20                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.345
# 21                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.346
# 22                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.347
# 23                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.348
# 24                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.386
# 25                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.387
# 26                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.387
# 27                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.388
# 28                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.388
# 29                     CanvasRenderingContext2D.arc 2017-12-16 15:49:50.389
# ...                                             ...                     ...
# 5505         CanvasRenderingContext2D.bezierCurveTo 2017-12-16 20:26:16.788
# 5506         CanvasRenderingContext2D.bezierCurveTo 2017-12-16 20:26:16.788
# 5507  CanvasRenderingContext2D.createRadialGradient 2017-12-16 20:26:16.789
# 5508  CanvasRenderingContext2D.createRadialGradient 2017-12-16 20:26:16.790
# 5509  CanvasRenderingContext2D.createRadialGradient 2017-12-16 20:26:16.793
# 5510  CanvasRenderingContext2D.createRadialGradient 2017-12-16 20:26:16.818
# 5511  CanvasRenderingContext2D.createRadialGradient 2017-12-16 20:26:16.822
# 5512  CanvasRenderingContext2D.createRadialGradient 2017-12-16 20:26:16.823
# 5513         CanvasRenderingContext2D.bezierCurveTo 2017-12-16 20:26:16.824
# 5514         CanvasRenderingContext2D.bezierCurveTo 2017-12-16 20:26:16.824
# 5515         CanvasRenderingContext2D.bezierCurveTo 2017-12-16 20:26:16.824
# 5516  CanvasRenderingContext2D.createRadialGradient 2017-12-16 20:26:16.824
# 5517  CanvasRenderingContext2D.createRadialGradient 2017-12-16 20:26:16.827
# 5518  CanvasRenderingContext2D.createRadialGradient 2017-12-16 20:26:16.833
# 5519                   CanvasRenderingContext2D.arc 2017-12-16 21:54:52.263
# 5520                   CanvasRenderingContext2D.arc 2017-12-16 15:51:49.313
# 5521                   CanvasRenderingContext2D.arc 2017-12-16 15:51:49.314
# 5522                   CanvasRenderingContext2D.arc 2017-12-16 15:51:49.315
# 5523                   CanvasRenderingContext2D.arc 2017-12-16 15:51:49.315
# 5524                   CanvasRenderingContext2D.arc 2017-12-16 15:51:49.316
# 5525                   CanvasRenderingContext2D.arc 2017-12-16 15:51:57.286
# 5526                   CanvasRenderingContext2D.arc 2017-12-16 15:51:57.287
# 5527                   CanvasRenderingContext2D.arc 2017-12-16 15:51:57.288
# 5528                   CanvasRenderingContext2D.arc 2017-12-16 15:51:57.288
# 5529                   CanvasRenderingContext2D.arc 2017-12-16 15:51:57.288
# 5530                   CanvasRenderingContext2D.arc 2017-12-16 21:51:13.309
# 5531                   CanvasRenderingContext2D.arc 2017-12-16 21:51:13.311
# 5532                   CanvasRenderingContext2D.arc 2017-12-16 21:51:13.314
# 5533                   CanvasRenderingContext2D.arc 2017-12-16 21:51:13.315
# 5534                   CanvasRenderingContext2D.arc 2017-12-16 21:51:13.315
#
#      value value_1000  value_len valid errors
# 0                              0  True
# 1                              0  True
# 2                              0  True
# 3                              0  True
# 4                              0  True
# 5                              0  True
# 6                              0  True
# 7                              0  True
# 8                              0  True
# 9                              0  True
# 10                             0  True
# 11                             0  True
# 12                             0  True
# 13                             0  True
# 14                             0  True
# 15                             0  True
# 16                             0  True
# 17                             0  True
# 18                             0  True
# 19                             0  True
# 20                             0  True
# 21                             0  True
# 22                             0  True
# 23                             0  True
# 24                             0  True
# 25                             0  True
# 26                             0  True
# 27                             0  True
# 28                             0  True
# 29                             0  True
# ...    ...        ...        ...   ...    ...
# 5505                           0  True
# 5506                           0  True
# 5507                           0  True
# 5508                           0  True
# 5509                           0  True
# 5510                           0  True
# 5511                           0  True
# 5512                           0  True
# 5513                           0  True
# 5514                           0  True
# 5515                           0  True
# 5516                           0  True
# 5517                           0  True
# 5518                           0  True
# 5519                           0  True
# 5520                           0  True
# 5521                           0  True
# 5522                           0  True
# 5523                           0  True
# 5524                           0  True
# 5525                           0  True
# 5526                           0  True
# 5527                           0  True
# 5528                           0  True
# 5529                           0  True
# 5530                           0  True
# 5531                           0  True
# 5532                           0  True
# 5533                           0  True
# 5534                           0  True
#
# [5535 rows x 30 columns]

# %%
good_data.groupBy('in_iframe').count().show()
# Out:
# +---------+------+
# |in_iframe| count|
# +---------+------+
# |     true|229460|
# |    false|908772|
# +---------+------+

# %%
good_data.groupBy('symbol').count().orderBy('count', ascending=False).show(100, False)
# Out:
# +---------------------------------------------------------------------+------+
# |symbol                                                               |count |
# +---------------------------------------------------------------------+------+
# |window.document.cookie                                               |341035|
# |window.navigator.userAgent                                           |147308|
# |window.Storage.getItem                                               |104671|
# |window.localStorage                                                  |87653 |
# |window.sessionStorage                                                |41690 |
# |window.Storage.setItem                                               |39289 |
# |window.Storage.removeItem                                            |26465 |
# |window.name                                                          |23416 |
# |CanvasRenderingContext2D.fillStyle                                   |19133 |
# |window.navigator.plugins[Shockwave Flash].description                |17791 |
# |window.screen.colorDepth                                             |14256 |
# |window.navigator.appName                                             |13198 |
# |CanvasRenderingContext2D.fill                                        |11968 |
# |CanvasRenderingContext2D.save                                        |11482 |
# |window.navigator.language                                            |11479 |
# |window.navigator.platform                                            |11358 |
# |CanvasRenderingContext2D.restore                                     |11340 |
# |CanvasRenderingContext2D.font                                        |9405  |
# |CanvasRenderingContext2D.stroke                                      |9059  |
# |window.navigator.plugins[Shockwave Flash].name                       |8846  |
# |CanvasRenderingContext2D.lineWidth                                   |8760  |
# |CanvasRenderingContext2D.strokeStyle                                 |8407  |
# |HTMLCanvasElement.width                                              |7609  |
# |CanvasRenderingContext2D.fillRect                                    |7541  |
# |HTMLCanvasElement.height                                             |7450  |
# |window.navigator.cookieEnabled                                       |6961  |
# |window.Storage.key                                                   |6910  |
# |window.Storage.length                                                |6829  |
# |HTMLCanvasElement.getContext                                         |6708  |
# |window.navigator.appVersion                                          |6689  |
# |CanvasRenderingContext2D.fillText                                    |6614  |
# |window.navigator.doNotTrack                                          |5129  |
# |CanvasRenderingContext2D.arc                                         |5107  |
# |CanvasRenderingContext2D.textBaseline                                |5064  |
# |HTMLCanvasElement.style                                              |4847  |
# |window.navigator.vendor                                              |4610  |
# |CanvasRenderingContext2D.textAlign                                   |4525  |
# |CanvasRenderingContext2D.measureText                                 |3830  |
# |CanvasRenderingContext2D.lineCap                                     |2671  |
# |CanvasRenderingContext2D.shadowBlur                                  |2664  |
# |window.navigator.product                                             |2636  |
# |CanvasRenderingContext2D.shadowColor                                 |2462  |
# |HTMLCanvasElement.nodeType                                           |2287  |
# |CanvasRenderingContext2D.shadowOffsetY                               |2274  |
# |CanvasRenderingContext2D.shadowOffsetX                               |2270  |
# |window.navigator.mimeTypes[application/x-shockwave-flash].type       |2235  |
# |window.navigator.plugins[Shockwave Flash].filename                   |2172  |
# |window.navigator.languages                                           |2021  |
# |CanvasRenderingContext2D.lineJoin                                    |1943  |
# |window.navigator.plugins[Shockwave Flash].length                     |1932  |
# |CanvasRenderingContext2D.globalCompositeOperation                    |1895  |
# |CanvasRenderingContext2D.createRadialGradient                        |1726  |
# |window.navigator.mimeTypes[application/futuresplash].type            |1687  |
# |window.screen.pixelDepth                                             |1540  |
# |CanvasRenderingContext2D.scale                                       |1507  |
# |window.navigator.plugins[Shockwave Flash].version                    |1506  |
# |HTMLCanvasElement.toDataURL                                          |1440  |
# |CanvasRenderingContext2D.bezierCurveTo                               |1390  |
# |CanvasRenderingContext2D.miterLimit                                  |1276  |
# |window.navigator.onLine                                              |1169  |
# |HTMLCanvasElement.nodeName                                           |1077  |
# |window.navigator.mimeTypes[application/futuresplash].suffixes        |991   |
# |window.navigator.mimeTypes[application/x-shockwave-flash].suffixes   |991   |
# |window.Storage.hasOwnProperty                                        |932   |
# |CanvasRenderingContext2D.rect                                        |851   |
# |RTCPeerConnection.localDescription                                   |789   |
# |CanvasRenderingContext2D.arcTo                                       |780   |
# |CanvasRenderingContext2D.createLinearGradient                        |773   |
# |window.navigator.mimeTypes[application/futuresplash].description     |740   |
# |window.navigator.mimeTypes[application/x-shockwave-flash].description|740   |
# |window.navigator.productSub                                          |736   |
# |HTMLCanvasElement.ownerDocument                                      |625   |
# |CanvasRenderingContext2D.rotate                                      |625   |
# |HTMLCanvasElement.className                                          |597   |
# |window.navigator.oscpu                                               |577   |
# |window.navigator.appCodeName                                         |523   |
# |HTMLCanvasElement.parentNode                                         |519   |
# |CanvasRenderingContext2D.strokeRect                                  |513   |
# |CanvasRenderingContext2D.getImageData                                |504   |
# |window.navigator.geolocation                                         |429   |
# |HTMLCanvasElement.tagName                                            |424   |
# |HTMLCanvasElement.id                                                 |407   |
# |CanvasRenderingContext2D.clip                                        |388   |
# |HTMLCanvasElement.setAttribute                                       |356   |
# |RTCPeerConnection.onicecandidate                                     |316   |
# |window.navigator.vendorSub                                           |279   |
# |window.navigator.buildID                                             |250   |
# |HTMLCanvasElement.addEventListener                                   |237   |
# |HTMLCanvasElement.attributes                                         |221   |
# |HTMLCanvasElement.onselectstart                                      |202   |
# |HTMLCanvasElement.classList                                          |202   |
# |CanvasRenderingContext2D.putImageData                                |199   |
# |HTMLCanvasElement.getElementsByTagName                               |193   |
# |HTMLCanvasElement.getAttribute                                       |176   |
# |HTMLCanvasElement.draggable                                          |169   |
# |RTCPeerConnection.iceGatheringState                                  |142   |
# |RTCPeerConnection.createDataChannel                                  |140   |
# |RTCPeerConnection.createOffer                                        |131   |
# |RTCPeerConnection.signalingState                                     |130   |
# |RTCPeerConnection.remoteDescription                                  |130   |
# +---------------------------------------------------------------------+------+
# only showing top 100 rows

# %%
locations = good_data.groupBy('location').count()
print(locations.count())
# Out:
# 19997

# %%
file_names = good_data.groupBy('file_name').count()
print(file_names.count())
# Out:
# 19997
